# %%
# 初始化数据
provinces = [
    "北京市",
    "天津市",
    "上海市",
    "重庆市",
    "河北省",
    "山西省",
    "辽宁省",
    "吉林省",
    "黑龙江省",
    "江苏省",
    "浙江省",
    "安徽省",
    "福建省",
    "江西省",
    "山东省",
    "河南省",
    "湖北省",
    "湖南省",
    "广东省",
    "海南省",
    "四川省",
    "贵州省",
    "云南省",
    "陕西省",
    "甘肃省",
    "青海省",
    "台湾省",
    "内蒙古自治区",
    "广西壮族自治区",
    "西藏自治区",
    "宁夏回族自治区",
    "新疆维吾尔自治区",
    "香港特别行政区",
    "澳门特别行政区",
]
province_abbreviations = [
    "京",
    "津",
    "沪",
    "渝",
    "冀",
    "晋",
    "辽",
    "吉",
    "黑",
    "苏",
    "浙",
    "皖",
    "闽",
    "赣",
    "鲁",
    "豫",
    "鄂",
    "湘",
    "粤",
    "琼",
    "川",
    "贵",
    "云",
    "陕",
    "甘",
    "青",
    "台",
    "内蒙古",
    "桂",
    "藏",
    "宁",
    "新",
    "港",
    "澳",
]
administrative_centers = [
    "北京",
    "天津",
    "上海",
    "重庆",
    "石家庄",
    "太原",
    "沈阳",
    "长春",
    "哈尔滨",
    "南京",
    "杭州",
    "合肥",
    "福州",
    "南昌",
    "济南",
    "郑州",
    "武汉",
    "长沙",
    "广州",
    "海口",
    "成都",
    "贵阳",
    "昆明",
    "西安",
    "兰州",
    "西宁",
    "台北",
    "呼和浩特",
    "南宁",
    "拉萨",
    "银川",
    "乌鲁木齐",
    "香港",
    "澳门",
]

# %%
import random as rd

while True:
    what_list=rd.randint(1, 3)
    what=rd.randint(0, 33)
    if what_list==1:
        user_answer1=input(provinces[what]+"的简称是什么？")
        if user_answer1==province_abbreviations[what]:
            print("回答正确！")
        if user_answer1!=province_abbreviations[what] and user_answer2!="退出":
            print("回答错误！正确答案是"+province_abbreviations[what])
        if user_answer1=="退出":
            break
        user_answer2=input(provinces[what]+"的行政中心是哪里？")
        if user_answer2==administrative_centers[what]:
            print("回答正确！")
        if user_answer2!=administrative_centers[what] and user_answer2!="退出":
            print("回答错误！正确答案是"+administrative_centers[what])
        if user_answer2=="退出":
            break
    if what_list==2:
        user_answer1=input(provinces_abbreviations[what]+"的全称是什么？")
        if user_answer1==province[what]:
            print("回答正确！")
        if user_answer1!=province[what] and user_answer2!="退出":
            print("回答错误！正确答案是"+province[what])
        if user_answer1=="退出":
            break
        user_answer2=input(provinces_abbreviations[what]+"对应的省份的行政中心是哪里？")
        if user_answer2==administrative_centers[what]:
            print("回答正确！")
        if user_answer2!=administrative_centers[what] and user_answer2!="退出":
            print("回答错误！正确答案是"+administrative_centers[what])
        if user_answer2=="退出":
            break
    if what_list==3:
        user_answer1=input(administrative_centers[what]+"对应省份的简称是什么？")
        if user_answer1==administrative_center_abbreviations[what]:
            print("回答正确！")
        if user_answer1!=administrative_center_abbreviations[what] and user_answer2!="退出":
            print("回答错误！正确答案是"+administrative_center_abbreviations[what])
        if user_answer1=="退出":
            break
        user_answer2=input(administrative_centers[what]+"是哪个省的行政中心？")
        if user_answer2==province[what]:
            print("回答正确！")
        if user_answer2!=province[what] and user_answer2!="退出":
            print("回答错误！正确答案是"+province[what])
        if user_answer2=="退出":
            break
# Out:
# 回答正确！
# 回答错误！正确答案是兰州
