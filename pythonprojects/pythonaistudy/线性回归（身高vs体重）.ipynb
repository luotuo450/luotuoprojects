# %%
import pandas as pd
data=pd.read_csv('weight vs height.csv')
data.head()
# Out:
#     height  weight
# 0  167.090  51.186
# 1  181.649  61.829
# 2  176.273  69.321
# 3  173.270  64.478
# 4  172.181  65.367

# %%
x=data.loc[:,"height"]
y=data.loc[:,"weight"]

# %%
from matplotlib import pyplot as plt
fig=plt.figure()
plt.scatter(x,y)
plt.title("height vs weight")
plt.xlabel("height")
plt.ylabel("weight")
plt.show()

# %%
x=x.values.reshape(-1,1)
y=y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
y_pred=model.predict(x)
print(y_pred)
# Out:
# [[54.48051087]
#  [62.48688411]
#  [59.53048171]
#  ...
#  [52.9649147 ]
#  [56.91888294]
#  [58.80237963]]

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("均方误差：",mean_squared_error(y,y_pred))
print("决定系数：",r2_score(y,y_pred))
# Out:
# 均方误差： 20.846870544718403
# 决定系数： 0.252866443578703

# %%
fig2=plt.figure()
plt.plot(x,y_pred,c="red")
plt.scatter(x,y)
plt.show()

# %%
y_test=model.predict([[151]]) #身高to体重
print(y_test)
# Out:
# [[45.63220087]]
